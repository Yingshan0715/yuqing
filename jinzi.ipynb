# %%
from ADB import AutoDatabank 
from ADB import set_pause, t180, swtime
from datetime import datetime, timedelta
from ADB import somedays
a = AutoDatabank(zhanghao=1, tmall_global=False, purchase_Behaviour='dp')

# %%
for i in ('A','I','PL'):
    ts='2019-1-7'
    te='2019-1-21'
    a.cp()
    a.tbtt(1,ts,te,3)
    a.tbtt(2,ts,te,3)
    a.tbtt(3,ts,te,3)
    a.tbtt(4,ts,te,3)
    a.tbtt(5,ts,te,3)
    a.tbtt(6,ts,te,3)
    a.tbtt(7,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-淘宝头条')
    a.cp()
    a.yhh(1,ts,te,3)
    a.yhh(2,ts,te,3)
    a.yhh(3,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-有好货')
    a.cp()
    a.bmqd(1,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-必买清单')
    a.cp()
    a.cnxh(1,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-猜你喜欢')
    a.cp()
    a.shyjs(2,ts,te,3)
    a.shyjs(1,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-生活研究所')
    a.cp()
    a.zb(1,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-直播')
    a.cp()
    a.wt(1,ts,te,3)
    a.wt(2,ts,te,3)
    a.wt(3,ts,te,3)
    a.wt(4,ts,te,3)
    a.wt(5,ts,te,3)
    a.wt(6,ts,te,3)
    a.wt(7,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-微淘')
    a.cp()
    a.mrhd(1,ts,te,3)
    a.mrhd(2,ts,te,3)
    a.zdy('新增1-21'+str(i),3)
    a.sp('XX-1-21'+str(i)+'-每日好店')
    
    ts1='2019-1-21'
    te1='2019-2-4'
    a.cp()
    a.tbtt(1,ts1,te1,3)
    a.tbtt(2,ts1,te1,3)
    a.tbtt(3,ts1,te1,3)
    a.tbtt(4,ts1,te1,3)
    a.tbtt(5,ts1,te1,3)
    a.tbtt(6,ts1,te1,3)
    a.tbtt(7,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-淘宝头条')
    a.cp()
    a.yhh(1,ts1,te1,3)
    a.yhh(2,ts1,te1,3)
    a.yhh(3,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-有好货')
    a.cp()
    a.bmqd(1,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-必买清单')
    a.cp()
    a.cnxh(1,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-猜你喜欢')
    a.cp()
    a.shyjs(2,ts1,te1,3)
    a.shyjs(1,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-生活研究所')
    a.cp()
    a.zb(1,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-直播')
    a.cp()
    a.wt(1,ts1,te1,3)
    a.wt(2,ts1,te1,3)
    a.wt(3,ts1,te1,3)
    a.wt(4,ts1,te1,3)
    a.wt(5,ts1,te1,3)
    a.wt(6,ts1,te1,3)
    a.wt(7,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-微淘')
    a.cp()
    a.mrhd(1,ts1,te1,3)
    a.mrhd(2,ts1,te1,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-每日好店')
    
    ts2='2019-2-4'
    te2='2019-2-17'
    a.cp()
    a.tbtt(1,ts2,te2,3)
    a.tbtt(2,ts2,te2,3)
    a.tbtt(3,ts2,te2,3)
    a.tbtt(4,ts2,te2,3)
    a.tbtt(5,ts2,te2,3)
    a.tbtt(6,ts2,te2,3)
    a.tbtt(7,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-淘宝头条')
    a.cp()
    a.yhh(1,ts2,te2,3)
    a.yhh(2,ts2,te2,3)
    a.yhh(3,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-有好货')
    a.cp()
    a.bmqd(1,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-必买清单')
    a.cp()
    a.cnxh(1,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-猜你喜欢')
    a.cp()
    a.shyjs(2,ts2,te2,3)
    a.shyjs(1,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-生活研究所')
    a.cp()
    a.zb(1,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-直播')
    a.cp()
    a.wt(1,ts2,te2,3)
    a.wt(2,ts2,te2,3)
    a.wt(3,ts2,te2,3)
    a.wt(4,ts2,te2,3)
    a.wt(5,ts2,te2,3)
    a.wt(6,ts2,te2,3)
    a.wt(7,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-微淘')
    a.cp()
    a.mrhd(1,ts2,te2,3)
    a.mrhd(2,ts2,te2,3)
    a.zdy('新增2-4'+str(i),3)
    a.sp('XX-2-4'+str(i)+'-每日好店')
